# %%
import pandas as pd

# %%
data = pd.read_csv('American_Housing_Data_20231209.csv')
data
# Out:
#        Zip Code      Price  Beds  Baths  Living Space                 Address  \
# 0         10013  3999000.0     2      3          1967       74 GRAND ST APT 3
# 1         10013  3999000.0     2      3          1967       74 GRAND ST APT 3
# 2         10014  1650000.0     1      1           718   140 CHARLES ST APT 4D
# 3         10014   760000.0     3      2          1538             38 JONES ST
# 4         10014  1100000.0     1      1           600    81 BEDFORD ST APT 3F
# ...         ...        ...   ...    ...           ...                     ...
# 39976     98199  2495000.0     4      4          3380         2626 27TH AVE W
# 39977     98199  2295000.0     4      4          2878         3215 32ND AVE W
# 39978     98199   950000.0     3      2          1380         3257 22ND AVE W
# 39979     98199   425000.0     2      1           856  3711 26TH PL W APT 102
# 39980     98199  1150000.0     3      3          2840         2911 25TH AVE W
#
#            City       State  Zip Code Population  Zip Code Density    County  \
# 0      New York    New York                29563           20967.9  New York
# 1      New York    New York                29563           20967.9  New York
# 2      New York    New York                29815           23740.9  New York
# 3      New York    New York                29815           23740.9  New York
# 4      New York    New York                29815           23740.9  New York
# ...         ...         ...                  ...               ...       ...
# 39976   Seattle  Washington                22890            2086.8      King
# 39977   Seattle  Washington                22890            2086.8      King
# 39978   Seattle  Washington                22890            2086.8      King
# 39979   Seattle  Washington                22890            2086.8      King
# 39980   Seattle  Washington                22890            2086.8      King
#
#        Median Household Income  Latitude  Longitude
# 0                     370046.0  40.72001  -74.00472
# 1                     370046.0  40.72001  -74.00472
# 2                     249880.0  40.73407  -74.00601
# 3                     249880.0  40.73407  -74.00601
# 4                     249880.0  40.73407  -74.00601
# ...                        ...       ...        ...
# 39976                 205611.0  47.65139 -122.40223
# 39977                 205611.0  47.65139 -122.40223
# 39978                 205611.0  47.65139 -122.40223
# 39979                 205611.0  47.65139 -122.40223
# 39980                 205611.0  47.65139 -122.40223
#
# [39981 rows x 14 columns]

# %%
data.columns
# Out:
# Index(['Zip Code', 'Price', 'Beds', 'Baths', 'Living Space', 'Address', 'City',
#        'State', 'Zip Code Population', 'Zip Code Density', 'County',
#        'Median Household Income', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Zip Code                     int64
# Price                      float64
# Beds                         int64
# Baths                        int64
# Living Space                 int64
# Address                     object
# City                        object
# State                       object
# Zip Code Population          int64
# Zip Code Density           float64
# County                      object
# Median Household Income    float64
# Latitude                   float64
# Longitude                  float64
# dtype: object

# %%
data.drop(['Zip Code','Address'],axis=True,inplace=True)

# %%
data
# Out:
#            Price  Beds  Baths  Living Space      City       State  \
# 0      3999000.0     2      3          1967  New York    New York
# 1      3999000.0     2      3          1967  New York    New York
# 2      1650000.0     1      1           718  New York    New York
# 3       760000.0     3      2          1538  New York    New York
# 4      1100000.0     1      1           600  New York    New York
# ...          ...   ...    ...           ...       ...         ...
# 39976  2495000.0     4      4          3380   Seattle  Washington
# 39977  2295000.0     4      4          2878   Seattle  Washington
# 39978   950000.0     3      2          1380   Seattle  Washington
# 39979   425000.0     2      1           856   Seattle  Washington
# 39980  1150000.0     3      3          2840   Seattle  Washington
#
#        Zip Code Population  Zip Code Density    County  \
# 0                    29563           20967.9  New York
# 1                    29563           20967.9  New York
# 2                    29815           23740.9  New York
# 3                    29815           23740.9  New York
# 4                    29815           23740.9  New York
# ...                    ...               ...       ...
# 39976                22890            2086.8      King
# 39977                22890            2086.8      King
# 39978                22890            2086.8      King
# 39979                22890            2086.8      King
# 39980                22890            2086.8      King
#
#        Median Household Income  Latitude  Longitude
# 0                     370046.0  40.72001  -74.00472
# 1                     370046.0  40.72001  -74.00472
# 2                     249880.0  40.73407  -74.00601
# 3                     249880.0  40.73407  -74.00601
# 4                     249880.0  40.73407  -74.00601
# ...                        ...       ...        ...
# 39976                 205611.0  47.65139 -122.40223
# 39977                 205611.0  47.65139 -122.40223
# 39978                 205611.0  47.65139 -122.40223
# 39979                 205611.0  47.65139 -122.40223
# 39980                 205611.0  47.65139 -122.40223
#
# [39981 rows x 12 columns]

# %%
data.duplicated().sum()
# Out:
# 1447

# %%
data = data.drop_duplicates()

# %%
data = data.reset_index(drop=True)
data
# Out:
#            Price  Beds  Baths  Living Space      City       State  \
# 0      3999000.0     2      3          1967  New York    New York
# 1      1650000.0     1      1           718  New York    New York
# 2       760000.0     3      2          1538  New York    New York
# 3      1100000.0     1      1           600  New York    New York
# 4       764900.0     1      1           643  New York    New York
# ...          ...   ...    ...           ...       ...         ...
# 38529  2495000.0     4      4          3380   Seattle  Washington
# 38530  2295000.0     4      4          2878   Seattle  Washington
# 38531   950000.0     3      2          1380   Seattle  Washington
# 38532   425000.0     2      1           856   Seattle  Washington
# 38533  1150000.0     3      3          2840   Seattle  Washington
#
#        Zip Code Population  Zip Code Density    County  \
# 0                    29563           20967.9  New York
# 1                    29815           23740.9  New York
# 2                    29815           23740.9  New York
# 3                    29815           23740.9  New York
# 4                    15514           20107.7  New York
# ...                    ...               ...       ...
# 38529                22890            2086.8      King
# 38530                22890            2086.8      King
# 38531                22890            2086.8      King
# 38532                22890            2086.8      King
# 38533                22890            2086.8      King
#
#        Median Household Income  Latitude  Longitude
# 0                     370046.0  40.72001  -74.00472
# 1                     249880.0  40.73407  -74.00601
# 2                     249880.0  40.73407  -74.00601
# 3                     249880.0  40.73407  -74.00601
# 4                     188289.0  40.75235  -73.97260
# ...                        ...       ...        ...
# 38529                 205611.0  47.65139 -122.40223
# 38530                 205611.0  47.65139 -122.40223
# 38531                 205611.0  47.65139 -122.40223
# 38532                 205611.0  47.65139 -122.40223
# 38533                 205611.0  47.65139 -122.40223
#
# [38534 rows x 12 columns]

# %%
data.isna().sum()
data.isnull().sum()
# Out:
# Price                      0
# Beds                       0
# Baths                      0
# Living Space               0
# City                       0
# State                      0
# Zip Code Population        0
# Zip Code Density           0
# County                     0
# Median Household Income    2
# Latitude                   0
# Longitude                  0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
data[['Median Household Income']]= imputer.fit_transform(data[['Median Household Income']])
data.isnull().sum()
# Out:
# Price                      0
# Beds                       0
# Baths                      0
# Living Space               0
# City                       0
# State                      0
# Zip Code Population        0
# Zip Code Density           0
# County                     0
# Median Household Income    0
# Latitude                   0
# Longitude                  0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

citys = LabelEncoder()

data['City'] = citys.fit_transform(data['City'])
data
# Out:
#            Price  Beds  Baths  Living Space  City       State  \
# 0      3999000.0     2      3          1967   150    New York
# 1      1650000.0     1      1           718   150    New York
# 2       760000.0     3      2          1538   150    New York
# 3      1100000.0     1      1           600   150    New York
# 4       764900.0     1      1           643   150    New York
# ...          ...   ...    ...           ...   ...         ...
# 38529  2495000.0     4      4          3380   204  Washington
# 38530  2295000.0     4      4          2878   204  Washington
# 38531   950000.0     3      2          1380   204  Washington
# 38532   425000.0     2      1           856   204  Washington
# 38533  1150000.0     3      3          2840   204  Washington
#
#        Zip Code Population  Zip Code Density    County  \
# 0                    29563           20967.9  New York
# 1                    29815           23740.9  New York
# 2                    29815           23740.9  New York
# 3                    29815           23740.9  New York
# 4                    15514           20107.7  New York
# ...                    ...               ...       ...
# 38529                22890            2086.8      King
# 38530                22890            2086.8      King
# 38531                22890            2086.8      King
# 38532                22890            2086.8      King
# 38533                22890            2086.8      King
#
#        Median Household Income  Latitude  Longitude
# 0                     370046.0  40.72001  -74.00472
# 1                     249880.0  40.73407  -74.00601
# 2                     249880.0  40.73407  -74.00601
# 3                     249880.0  40.73407  -74.00601
# 4                     188289.0  40.75235  -73.97260
# ...                        ...       ...        ...
# 38529                 205611.0  47.65139 -122.40223
# 38530                 205611.0  47.65139 -122.40223
# 38531                 205611.0  47.65139 -122.40223
# 38532                 205611.0  47.65139 -122.40223
# 38533                 205611.0  47.65139 -122.40223
#
# [38534 rows x 12 columns]

# %%
states = LabelEncoder()

data['State'] = states.fit_transform(data['State'])
data
# Out:
#            Price  Beds  Baths  Living Space  City  State  Zip Code Population  \
# 0      3999000.0     2      3          1967   150     18                29563
# 1      1650000.0     1      1           718   150     18                29815
# 2       760000.0     3      2          1538   150     18                29815
# 3      1100000.0     1      1           600   150     18                29815
# 4       764900.0     1      1           643   150     18                15514
# ...          ...   ...    ...           ...   ...    ...                  ...
# 38529  2495000.0     4      4          3380   204     27                22890
# 38530  2295000.0     4      4          2878   204     27                22890
# 38531   950000.0     3      2          1380   204     27                22890
# 38532   425000.0     2      1           856   204     27                22890
# 38533  1150000.0     3      3          2840   204     27                22890
#
#        Zip Code Density    County  Median Household Income  Latitude  \
# 0               20967.9  New York                 370046.0  40.72001
# 1               23740.9  New York                 249880.0  40.73407
# 2               23740.9  New York                 249880.0  40.73407
# 3               23740.9  New York                 249880.0  40.73407
# 4               20107.7  New York                 188289.0  40.75235
# ...                 ...       ...                      ...       ...
# 38529            2086.8      King                 205611.0  47.65139
# 38530            2086.8      King                 205611.0  47.65139
# 38531            2086.8      King                 205611.0  47.65139
# 38532            2086.8      King                 205611.0  47.65139
# 38533            2086.8      King                 205611.0  47.65139
#
#        Longitude
# 0      -74.00472
# 1      -74.00601
# 2      -74.00601
# 3      -74.00601
# 4      -73.97260
# ...          ...
# 38529 -122.40223
# 38530 -122.40223
# 38531 -122.40223
# 38532 -122.40223
# 38533 -122.40223
#
# [38534 rows x 12 columns]

# %%
countys = LabelEncoder()

data['County'] = countys.fit_transform(data['County'])
data
# Out:
#            Price  Beds  Baths  Living Space  City  State  Zip Code Population  \
# 0      3999000.0     2      3          1967   150     18                29563
# 1      1650000.0     1      1           718   150     18                29815
# 2       760000.0     3      2          1538   150     18                29815
# 3      1100000.0     1      1           600   150     18                29815
# 4       764900.0     1      1           643   150     18                15514
# ...          ...   ...    ...           ...   ...    ...                  ...
# 38529  2495000.0     4      4          3380   204     27                22890
# 38530  2295000.0     4      4          2878   204     27                22890
# 38531   950000.0     3      2          1380   204     27                22890
# 38532   425000.0     2      1           856   204     27                22890
# 38533  1150000.0     3      3          2840   204     27                22890
#
#        Zip Code Density  County  Median Household Income  Latitude  Longitude
# 0               20967.9      57                 370046.0  40.72001  -74.00472
# 1               23740.9      57                 249880.0  40.73407  -74.00601
# 2               23740.9      57                 249880.0  40.73407  -74.00601
# 3               23740.9      57                 249880.0  40.73407  -74.00601
# 4               20107.7      57                 188289.0  40.75235  -73.97260
# ...                 ...     ...                      ...       ...        ...
# 38529            2086.8      46                 205611.0  47.65139 -122.40223
# 38530            2086.8      46                 205611.0  47.65139 -122.40223
# 38531            2086.8      46                 205611.0  47.65139 -122.40223
# 38532            2086.8      46                 205611.0  47.65139 -122.40223
# 38533            2086.8      46                 205611.0  47.65139 -122.40223
#
# [38534 rows x 12 columns]

# %%
data.dtypes
# Out:
# Price                      float64
# Beds                         int64
# Baths                        int64
# Living Space                 int64
# City                         int32
# State                        int32
# Zip Code Population          int64
# Zip Code Density           float64
# County                       int32
# Median Household Income    float64
# Latitude                   float64
# Longitude                  float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Price', 'Beds', 'Baths', 'Living Space', 'City', 'State',
#        'Zip Code Population', 'Zip Code Density', 'County',
#        'Median Household Income', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

i=1

column_names = ['Price', 'Beds', 'Baths', 'Living Space',
       'Zip Code Population', 'Zip Code Density', 
       'Median Household Income', 'Latitude', 'Longitude']

for col in column_names:
    plt.subplots_adjust(wspace=0.6,hspace=0.6)
    plt.subplot(3,3,i)
    i=i+1
    plt.boxplot(data[col],patch_artist=True)
    plt.title(col)

# %%
print(data.shape)

import numpy as np
# Out:
# (38534, 12)

# %%
outlier_columns = ['Price', 'Beds', 'Baths', 'Living Space',
       'Zip Code Population', 'Zip Code Density', 
       'Median Household Income', 'Latitude', 'Longitude']

i=1

for col in outlier_columns:
    Q1=data[col].quantile(0.25)
    Q3=data[col].quantile(0.75)
    
    IQR=Q3-Q1
    
    lower = Q1 - 1.5*IQR
    upper = Q3 + 1.5*IQR
    
    upper_index=np.where(data[col] >= upper)[0]
    lower_index=np.where(data[col] <= lower)[0]
    
    data.drop(index= upper_index , inplace = True)
    data.drop(index= lower_index , inplace = True)
    
    plt.subplots_adjust(wspace=0.6,hspace=0.6)
    plt.subplot(3,3,i)
    i=i+1
    plt.boxplot(data[col])
    plt.title(col)
    
    data.reset_index(inplace=True)
    data.drop('index',axis=1,inplace=True)
    #data.reset_index(drop=True, inplace=True)

# %%
print(data.shape)
# Out:
# (29369, 12)

# %%
correlation=data.corr()
correlation
# Out:
#                             Price      Beds     Baths  Living Space      City  \
# Price                    1.000000  0.204750  0.408255      0.428086  0.107577
# Beds                     0.204750  1.000000  0.512336      0.658574 -0.034248
# Baths                    0.408255  0.512336  1.000000      0.703188 -0.033678
# Living Space             0.428086  0.658574  0.703188      1.000000 -0.028734
# City                     0.107577 -0.034248 -0.033678     -0.028734  1.000000
# State                   -0.173927  0.097574  0.086594      0.103812 -0.093696
# Zip Code Population      0.039564  0.104973  0.091919      0.032549 -0.035917
# Zip Code Density         0.172135 -0.196477 -0.176726     -0.243263  0.027670
# County                  -0.023091  0.015431 -0.037871     -0.017375  0.310814
# Median Household Income  0.549075 -0.019792  0.236912      0.216778  0.099328
# Latitude                -0.072191 -0.034393 -0.113255     -0.072986  0.082577
# Longitude               -0.325984  0.060117  0.045877      0.022542 -0.167196
#
#                             State  Zip Code Population  Zip Code Density  \
# Price                   -0.173927             0.039564          0.172135
# Beds                     0.097574             0.104973         -0.196477
# Baths                    0.086594             0.091919         -0.176726
# Living Space             0.103812             0.032549         -0.243263
# City                    -0.093696            -0.035917          0.027670
# State                    1.000000             0.071974         -0.127834
# Zip Code Population      0.071974             1.000000          0.063119
# Zip Code Density        -0.127834             0.063119          1.000000
# County                   0.091043            -0.046276         -0.063096
# Median Household Income -0.051450            -0.019373          0.009901
# Latitude                 0.035083            -0.117287          0.235512
# Longitude                0.324896            -0.006189         -0.091194
#
#                            County  Median Household Income  Latitude  \
# Price                   -0.023091                 0.549075 -0.072191
# Beds                     0.015431                -0.019792 -0.034393
# Baths                   -0.037871                 0.236912 -0.113255
# Living Space            -0.017375                 0.216778 -0.072986
# City                     0.310814                 0.099328  0.082577
# State                    0.091043                -0.051450  0.035083
# Zip Code Population     -0.046276                -0.019373 -0.117287
# Zip Code Density        -0.063096                 0.009901  0.235512
# County                   1.000000                 0.003129  0.001189
# Median Household Income  0.003129                 1.000000  0.037722
# Latitude                 0.001189                 0.037722  1.000000
# Longitude                0.086756                -0.200673 -0.033456
#
#                          Longitude
# Price                    -0.325984
# Beds                      0.060117
# Baths                     0.045877
# Living Space              0.022542
# City                     -0.167196
# State                     0.324896
# Zip Code Population      -0.006189
# Zip Code Density         -0.091194
# County                    0.086756
# Median Household Income  -0.200673
# Latitude                 -0.033456
# Longitude                 1.000000

# %%
data.columns
data.drop(['Zip Code Population', 'County','Latitude'],axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error , mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
x=data.drop('Price', axis = 1)

# %%
y=data['Price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=120)

# %%
model=LinearRegression()

model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([-6.93813474e+02,  4.64505941e+04,  1.10720778e+02,  1.06205290e+02,
#        -2.42206771e+03,  5.11304770e+01,  2.74434716e+00, -3.43194108e+03])

# %%
model.intercept_
# Out:
# -555593.2998284404

# %%
model.score(x_test,y_test)
# Out:
# 0.5488888051148184

# %%
model.score(x_train,y_train)
# Out:
# 0.5359520871805078

# %%
y_pred=model.predict(x_test)

# %%
pd.DataFrame({'True Value' : y_test ,'Predicted Value' : y_pred })
# Out:
#        True Value  Predicted Value
# 1573     597500.0    543518.685528
# 36       499999.0    397754.207375
# 27323    675000.0    729469.460177
# 1694     297715.0    340154.237003
# 17676    439000.0    430331.777080
# ...           ...              ...
# 19875    277000.0    471242.988660
# 19046    499950.0    456572.796254
# 13608    325000.0    246176.144835
# 14229    216161.0    267717.510478
# 1826     264900.0    308568.341230
#
# [8811 rows x 2 columns]

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 113388.09666771036

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 24127163224.10929

# %%
x
# Out:
#        Beds  Baths  Living Space  City  State  Zip Code Density  \
# 0         6      2          1920   213     18            3980.1
# 1         4      2          1853   213     18            3980.1
# 2         4      3          1980   213     18            3980.1
# 3         3      1          2288   213     18            3980.1
# 4         4      2          2511   213     18            3980.1
# ...     ...    ...           ...   ...    ...               ...
# 29364     3      2          2880   204     27            2070.4
# 29365     3      1          1230   204     27            2070.4
# 29366     2      2          1010   204     27            2070.4
# 29367     4      3          2274   204     27            2070.4
# 29368     3      1           960   204     27            2070.4
#
#        Median Household Income  Longitude
# 0                     118113.0  -74.09564
# 1                     118113.0  -74.09564
# 2                     118113.0  -74.09564
# 3                     118113.0  -74.09564
# 4                     118113.0  -74.09564
# ...                        ...        ...
# 29364                 133779.0 -122.24735
# 29365                 133779.0 -122.24735
# 29366                 133779.0 -122.24735
# 29367                 133779.0 -122.24735
# 29368                 133779.0 -122.24735
#
# [29369 rows x 8 columns]

# %%
model.predict([[4,1,2200,204,25,3970,1181113.0,-74.05]])
# Out:
# C:\Users\gkcha\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3391289.26947768])

# %%
import joblib

# %%
joblib.dump(model,'usa')
# Out:
# ['usa']
